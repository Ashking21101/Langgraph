# %% [markdown]
# # Very Imp, we dont know how many worker node will be there before hand, so we use "SEND" api to dynamically send tasks to workernodes in parallel

# %% [markdown]
# # Better prompts and some additonal things

# %%
from __future__ import annotations

import operator
from pathlib import Path
from typing import TypedDict, List, Annotated, Literal

from pydantic import BaseModel, Field
from langgraph.graph import StateGraph, START, END
from langgraph.types import Send

from langchain_openai import ChatOpenAI
from langchain_core.messages import SystemMessage, HumanMessage

# %%
class Task(BaseModel):
    id: int
    title: str

    goal: str = Field(...,description="One sentence describing what the reader should be able to do/understand after this section.",)
    bullets: List[str] = Field(...,min_length=3,max_length=5,description="3-5 concrete, non-overlapping subpoints to cover in this section.",)
    target_words: int = Field(...,description="Target word count for this section (120-450).",)
    section_type: Literal["intro", "core", "examples", "checklist", "common_mistakes", "conclusion"] = Field(...,description="Use 'common_mistakes' exactly once in the plan.",)

# %%
class Plan(BaseModel):
    blog_title: str
    audience: str = Field(..., description="Who this blog is for.")
    tone: str = Field(..., description="Writing tone (e.g., practical, crisp).")
    tasks: List[Task]

# %%
class State(TypedDict):
    topic: str
    plan: Plan
    sections: Annotated[List[str], operator.add]  # reducer concatenates worker outputs
    final: str

# %%
llm = ChatOpenAI(model="gpt-4.1-mini")

# %%
def orchestrator(state: State) -> dict:
    planner = llm.with_structured_output(Plan)

    plan = planner.invoke(
        [
            SystemMessage(
                content=(
                    "You are a senior technical writer and developer advocate. Your job is to produce a "
                    "highly actionable outline for a technical blog post.\n\n"
                    "Hard requirements:\n"
                    "- Create 5-7 sections (tasks) that fit a technical blog.\n"
                    "- Each section must include:\n"
                    "  1) goal (1 sentence: what the reader can do/understand after the section)\n"
                    "  2) 3-5 bullets that are concrete, specific, and non-overlapping\n"
                    "  3) target word count (120-450)\n"
                    "- Include EXACTLY ONE section with section_type='common_mistakes'.\n\n"
                    "Make it technical (not generic):\n"
                    "- Assume the reader is a developer; use correct terminology.\n"
                    "- Prefer design/engineering structure: problem → intuition → approach → implementation → "
                    "trade-offs → testing/observability → conclusion.\n"
                    "- Bullets must be actionable and testable (e.g., 'Show a minimal code snippet for X', "
                    "'Explain why Y fails under Z condition', 'Add a checklist for production readiness').\n"
                    "- Explicitly include at least ONE of the following somewhere in the plan (as bullets):\n"
                    "  * a minimal working example (MWE) or code sketch\n"
                    "  * edge cases / failure modes\n"
                    "  * performance/cost considerations\n"
                    "  * security/privacy considerations (if relevant)\n"
                    "  * debugging tips / observability (logs, metrics, traces)\n"
                    "- Avoid vague bullets like 'Explain X' or 'Discuss Y'. Every bullet should state what "
                    "to build/compare/measure/verify.\n\n"
                    "Ordering guidance:\n"
                    "- Start with a crisp intro and problem framing.\n"
                    "- Build core concepts before advanced details.\n"
                    "- Include one section for common mistakes and how to avoid them.\n"
                    "- End with a practical summary/checklist and next steps.\n\n"
                    "Output must strictly match the Plan schema."
                )
            ),
            HumanMessage(content=f"Topic: {state['topic']}"),
        ]
    )

    return {"plan": plan}

# %%
def fanout(state: State):
    return [Send("worker",{"task": task, "topic": state["topic"], "plan": state["plan"]},)for task in state["plan"].tasks]

# %%
def worker(payload: dict) -> dict:

    task = payload["task"]
    topic = payload["topic"]
    plan = payload["plan"]

    bullets_text = "\n- " + "\n- ".join(task.bullets)

    section_md = llm.invoke(
        [
            SystemMessage(
    content=(
        "You are a senior technical writer and developer advocate. Write ONE section of a technical blog post in Markdown.\n\n"
        "Hard constraints:\n"
        "- Follow the provided Goal and cover ALL Bullets in order (do not skip or merge bullets).\n"
        "- Stay close to the Target words (±15%).\n"
        "- Output ONLY the section content in Markdown (no blog title H1, no extra commentary).\n\n"
        "Technical quality bar:\n"
        "- Be precise and implementation-oriented (developers should be able to apply it).\n"
        "- Prefer concrete details over abstractions: APIs, data structures, protocols, and exact terms.\n"
        "- When relevant, include at least one of:\n"
        "  * a small code snippet (minimal, correct, and idiomatic)\n"
        "  * a tiny example input/output\n"
        "  * a checklist of steps\n"
        "  * a diagram described in text (e.g., 'Flow: A -> B -> C')\n"
        "- Explain trade-offs briefly (performance, cost, complexity, reliability).\n"
        "- Call out edge cases / failure modes and what to do about them.\n"
        "- If you mention a best practice, add the 'why' in one sentence.\n\n"
        "Markdown style:\n"
        "- Start with a '## <Section Title>' heading.\n"
        "- Use short paragraphs, bullet lists where helpful, and code fences for code.\n"
        "- Avoid fluff. Avoid marketing language.\n"
        "- If you include code, keep it focused on the bullet being addressed.\n"
    )
)
,
            HumanMessage(
                content=(
                    f"Blog: {plan.blog_title}\n"
                    f"Audience: {plan.audience}\n"
                    f"Tone: {plan.tone}\n"
                    f"Topic: {topic}\n\n"
                    f"Section: {task.title}\n"
                    f"Section type: {task.section_type}\n"
                    f"Goal: {task.goal}\n"
                    f"Target words: {task.target_words}\n"
                    f"Bullets:{bullets_text}\n"
                )
            ),
        ]
    ).content.strip()

    return {"sections": [section_md]}

# %%
def reducer(state: State) -> dict:

    title = state["plan"].blog_title
    body = "\n\n".join(state["sections"]).strip()
    
    final_md = f"# {title}\n\n{body}\n"

    # Save to file
    filename = "".join(c if c.isalnum() or c in (" ", "_", "-") else "" for c in title)
    filename = filename.strip().lower().replace(" ", "_") + ".md"
    Path(filename).write_text(final_md, encoding="utf-8")

    return {"final": final_md}

# %%
# -----------------------------
# 5) Graph
# -----------------------------
g = StateGraph(State)
g.add_node("orchestrator", orchestrator)
g.add_node("worker", worker)
g.add_node("reducer", reducer)

g.add_edge(START, "orchestrator")
g.add_conditional_edges("orchestrator", fanout, ["worker"])
g.add_edge("worker", "reducer")
g.add_edge("reducer", END)

app = g.compile()

app

# %%
out = app.invoke({"topic": "Write a blog on Self Attention", "sections": []})

# %%
out
# Out:
# {'topic': 'Write a blog on Self Attention',
#  'plan': Plan(blog_title="Demystifying Self-Attention: A Developer's Guide to Understanding and Implementing Transformer Mechanisms", audience='Developers and engineers interested in deep learning architectures, specifically transformers and attention mechanisms.', tone='Practical and technical with clear code examples', tasks=[Task(id=1, title='Introduction to Self-Attention and Its Importance', goal='Explain what self-attention is and why it is fundamental in modern deep learning architectures like transformers.', bullets=['Define self-attention with emphasis on its mechanism of relating different positions of a single sequence to compute representations.', 'Outline the problem self-attention solves compared to traditional sequential models like RNNs or CNNs, especially in terms of capturing long-range dependencies.', 'Highlight use cases where self-attention is particularly effective, such as NLP, vision transformers, and speech recognition.', 'Introduce the notion of scalability and parallelism benefits over recurrent models.', 'Briefly mention transformer architecture as the main consumer of self-attention modules.'], target_words=300, section_type='intro'), Task(id=2, title='Core Concepts and Mathematical Formulation of Self-Attention', goal='Enable readers to understand and implement the self-attention mechanism mathematically and programmatically.', bullets=['Present the key components: Query, Key, and Value matrices and their roles in self-attention computation.', 'Provide the formula for scaled dot-product attention with explanation of each term and why scaling is necessary.', 'Explain how attention weights are calculated via softmax and why normalization matters for stability.', "Illustrate positional encoding's importance since self-attention alone is permutation-invariant.", 'Include a minimal working example (MWE) of scaled dot-product attention calculation in Python using numpy or PyTorch, focusing on matrix operations.'], target_words=400, section_type='core'), Task(id=3, title='Implementing Multi-Head Self-Attention: Design and Trade-offs', goal='Show readers how to implement multi-head self-attention and discuss design decisions and trade-offs involved.', bullets=['Explain the intuition behind multi-head attention to capture information from different representation subspaces.', 'Outline how to split Q, K, V matrices into multiple heads, perform parallel attention, then concatenate results.', 'Provide a code snippet sketch implementing a multi-head attention module, including linear projections and concatenation steps.', 'Discuss computational cost and memory overhead considerations, providing formula for complexity relative to sequence length and number of heads.', 'Highlight impact on model expressivity and performance vs. resource usage.'], target_words=450, section_type='core'), Task(id=4, title='Common Mistakes and Debugging Tips When Working with Self-Attention', goal='Help developers avoid frequent pitfalls and effectively debug self-attention implementations.', bullets=['Explain common bugs such as shape mismatches in Q,K,V projections and how to systematically verify tensor dimensions at each step.', 'Describe typical off-by-one errors in sequence length handling, including padding and mask integration.', 'Discuss the importance of the attention mask in preventing leakage from future tokens in autoregressive models and how improper masking affects training.', 'Provide debugging tips using logging attention weights and intermediate outputs to ensure weights sum to 1 and distributions make sense.', 'Highlight performance bottlenecks and recommend profiling tools or strategies to optimize matrix multiplications and memory usage.'], target_words=350, section_type='common_mistakes'), Task(id=5, title='Testing, Observability, and Performance Considerations', goal='Teach readers how to test self-attention modules thoroughly and monitor their performance and correctness in production.', bullets=['Suggest uni ...
#  'sections': ['## Introduction to Self-Attention and Its Importance\n\nSelf-attention is a mechanism that computes a representation of a sequence by relating different positions within that same sequence. Unlike methods that process input tokens independently or in strict order, self-attention dynamically weighs the influence of each token on every other token, enabling the model to capture contextual relationships regardless of their distance. Concretely, for each position in the input sequence, self-attention produces a weighted sum of all positions’ embeddings, where the weights reflect pairwise relevance learned via query-key similarity.\n\nTraditional sequential models like RNNs or CNNs face challenges when modeling long-range dependencies. RNNs suffer from vanishing gradients and must process data token-by-token, limiting their ability to capture distant interactions efficiently. CNNs leverage local filters, requiring many layers to capture broad context. Self-attention addresses these by allowing direct connections between any two positions in the sequence, enabling global context modeling in a single layer. This leads to better gradient flow and more flexible representations.\n\nSelf-attention is especially effective in domains such as:\n\n- **Natural Language Processing (NLP):** It models word dependencies regardless of their distance, improving tasks like translation or sentiment analysis.\n- **Vision Transformers (ViT):** Applies self-attention over image patches to capture global spatial relationships, replacing convolutions.\n- **Speech Recognition:** Captures temporal dependencies across audio frames more effectively than traditional methods.\n\nA key advantage of self-attention over recurrent approaches is scalability via parallelism. Since all sequence positions are processed simultaneously, implementations can leverage GPU acceleration more efficiently, leading to significant speedups during training and inference.\n\nThe transformer architecture is the primary consumer of self-attention modules. Transformers stack multiple self-attention layers combined with feed-forward networks to build powerful sequence models, forming the backbone of state-of-the-art models like BERT and GPT. This architecture’s success underscores the foundational importance of self-attention in modern deep learning.',
#   '## Core Concepts and Mathematical Formulation of Self-Attention\n\nSelf-attention is a mechanism that allows each element in a sequence to attend to other elements dynamically, enabling models like Transformers to capture contextual relationships effectively. The core components are **Query (Q)**, **Key (K)**, and **Value (V)** matrices, which are linear projections of the input embeddings:\n\n- **Query (Q)**: Represents the current element seeking information.\n- **Key (K)**: Represents candidates to be attended to.\n- **Value (V)**: Holds the actual information to aggregate based on attention scores.\n\nThese components are obtained by multiplying the input matrix \\(X \\in \\mathbb{R}^{n \\times d}\\) (with sequence length \\(n\\) and embedding dimension \\(d\\)) by learned weight matrices \\(W_Q, W_K, W_V \\in \\mathbb{R}^{d \\times d_k}\\):\n\n\\[\nQ = X W_Q, \\quad K = X W_K, \\quad V = X W_V\n\\]\n\n### Scaled Dot-Product Attention Formula\n\nThe attention mechanism computes a weighted sum of values, where weights reflect the similarity between queries and keys. Mathematically:\n\n\\[\n\\text{Attention}(Q, K, V) = \\text{softmax} \\left( \\frac{Q K^\\top}{\\sqrt{d_k}} \\right) V\n\\]\n\nBreaking down the terms:\n\n- \\(Q K^\\top\\) computes the raw compatibility scores (dot products) between each query and key vector pair.\n- Dividing by \\(\\sqrt{d_k}\\) scales the scores to avoid large magnitudes, which can push softmax into regions with very small gradients, causing learning instabilities.\n- The softmax function normalizes these scores into attention weights that sum to 1 for each query.\n- Finally, these attention weights weight the value vectors \\(V\\) to produce the output.\n\n### Attention Weights and Normalization\n\nUsing softmax ensures attention weights are positive and sum to 1, acting as a probability distribution over keys for each query. This normalization is critical for numerical stability and interpretability of the weights:\n\n- **Stability:** Prevents large score values from saturating softmax and causing vanishing gradients.\n- **Meaningfulness:** Allows attention to be viewed as focusing proportions on various parts of the input.\n\n### Positional Encoding: Adding Order Information\n\nSelf-attention alone is permutation-invariant since it treats the input as a set rather than a sequence. To incorporate token order, *positional encodings* are added to the input embeddings before projecting to Q, K, and V. Popular schemes include sinusoidal positional encodings:\n\n\\[\n\\text{PE}_{(pos, 2i)} = \\sin\\left(\\frac{pos}{10000^{2i / d}}\\right), \\quad \\text{PE}_{(pos, 2i+1)} = \\cos\\left(\\frac{pos}{10000^{2i / d}}\\right)\n\\]\n\nThis encoding injects relative and absolute position information, allowing the model to distinguish different word orders.\n\n### Minimal Working Example: Scaled Dot-Product Attention with PyTorch\n\n```python\nimport torch\nimport torch.nn.functional as F\n\n# Example input: 2 tokens, embedding dim = 4\nX = torch.tensor([[1., 0., 1., 0.],\n                  [0., 2., 0., 2.]])  # Shape: (2, 4)\n\n# Weight matrices (randomly initialized for demonstration)\nW_Q = torch.randn(4, 4)\nW_K = torch.randn(4, 4)\nW_V = torch.randn(4, 4)\n\n# Compute Q, K, V\nQ = X @ W_Q        # Shape: (2, 4)\nK = X @ W_K        # Shape: (2, 4)\nV = X @ W_V        # Shape: (2, 4)\n\n# Compute scaled dot-product attention\nd_k = Q.size(-1)\nscores = Q @ K.T / torch.sqrt(torch.tensor(d_k, dtype=torch.float32))  # Shape: (2, 2)\n\n# Apply softmax to get attention weights\nattn_weights = F.softmax(scores, dim=-1)  # Shape: (2, 2)\n\n# Weighted sum of V\noutput = attn_weights @ V  # Shape: (2, 4)\n\nprint("Attention weights:\\n", attn_weights)\nprint("Output:\\n", output)\n```\n\nThis snippet shows all matrix operations to implement scaled dot-product attention on a mini-batch of two tokens, highlighting the multiplication order and normalization. The model learns \\(W_Q\\), \\(W_K\\), and \\(W_V\\) ...
#   '## Implementing Multi-Head Self-Attention: Design and Trade-offs\n\nMulti-head self-attention enhances the original attention mechanism by allowing the model to jointly attend to information from different representation subspaces at different positions. Intuitively, each head learns to focus on a distinct aspect or pattern of the input sequence, capturing richer and more diverse features than a single attention mechanism could. For example, one head might capture syntactic relationships while another captures semantic relatedness.\n\n### Splitting into Multiple Heads\n\nGiven input representations, multi-head attention first projects inputs into query (Q), key (K), and value (V) matrices. These are then split across the feature dimension into multiple heads. Each head independently performs scaled dot-product attention in parallel over a smaller dimensional subspace. After attention scores are computed and applied to the values, the resulting outputs from each head are concatenated and passed through a final linear projection to combine the heads back into the original dimension:\n\n```\nFlow: Input X\n   -> Linear projections to Q, K, V\n   -> Split Q, K, V into h heads: (batch, seq_len, d_model/h)\n   -> For each head: scaled dot-product attention in parallel\n   -> Concatenate h outputs: (batch, seq_len, d_model)\n   -> Final linear projection\n```\n\n### Code Sketch for Multi-Head Attention\n\n```python\nimport torch\nimport torch.nn as nn\nimport torch.nn.functional as F\n\nclass MultiHeadAttention(nn.Module):\n    def __init__(self, d_model, num_heads):\n        super().__init__()\n        assert d_model % num_heads == 0, "d_model must be divisible by num_heads"\n        self.num_heads = num_heads\n        self.head_dim = d_model // num_heads\n\n        self.q_linear = nn.Linear(d_model, d_model)\n        self.k_linear = nn.Linear(d_model, d_model)\n        self.v_linear = nn.Linear(d_model, d_model)\n        self.out_linear = nn.Linear(d_model, d_model)\n\n    def forward(self, x):\n        batch_size, seq_len, _ = x.size()\n\n        # Project inputs to Q, K, V and split into heads\n        Q = self.q_linear(x).view(batch_size, seq_len, self.num_heads, self.head_dim).transpose(1, 2)\n        K = self.k_linear(x).view(batch_size, seq_len, self.num_heads, self.head_dim).transpose(1, 2)\n        V = self.v_linear(x).view(batch_size, seq_len, self.num_heads, self.head_dim).transpose(1, 2)\n\n        # Scaled dot-product attention for each head\n        scores = torch.matmul(Q, K.transpose(-2, -1)) / (self.head_dim ** 0.5)\n        attn = F.softmax(scores, dim=-1)\n        context = torch.matmul(attn, V)  # (batch, heads, seq_len, head_dim)\n\n        # Concatenate heads\n        context = context.transpose(1, 2).contiguous().view(batch_size, seq_len, -1)\n\n        # Final linear layer output\n        output = self.out_linear(context)\n        return output\n```\n\n### Computational Cost and Memory Considerations\n\nThe attention operation’s time and memory complexity scale as:\n\n\\[\nO(h \\times seq\\_len^2 \\times \\frac{d_{model}}{h}) = O(seq\\_len^2 \\times d_{model})\n\\]\n\nwhere:\n\n- \\( h \\) = number of heads,\n- \\( seq\\_len \\) = input sequence length,\n- \\( d_{model} \\) = total hidden size.\n\nThis shows total complexity is linear in the model dimension but quadratic in the sequence length, dominated by the pairwise dot products between queries and keys. Increasing the number of heads \\( h \\) does not increase complexity asymptotically since the dimension per head decreases proportionally. However, in practice, more heads introduce additional overhead for splitting, parallelism, and concatenation.\n\nMemory consumption also grows proportional to \\( seq\\_len^2 \\) due to storing attention weights for all token pairs in each head, which can be a bottleneck for very long sequences.\n\n### Expressivity vs. Resource Trade-offs\n\nUsing multiple heads boosts model expressivity by enabling the network to  ...
#   '## Common Mistakes and Debugging Tips When Working with Self-Attention\n\n### Shape Mismatches in Q, K, V Projections\nA frequent bug in implementing self-attention arises from incorrect tensor shapes in query (Q), key (K), and value (V) projections. Typically, inputs have shape `(batch_size, seq_len, embed_dim)`. After linear projection to Q, K, V, ensure shapes are consistent:\n\n```python\n# Example for single attention head\nQ = linear_query(x)  # shape: (batch_size, seq_len, head_dim)\nK = linear_key(x)    # shape: (batch_size, seq_len, head_dim)\nV = linear_value(x)  # shape: (batch_size, seq_len, head_dim)\n```\n\n**How to verify:** At each step, print or assert shapes:\n\n```python\nassert Q.shape == K.shape == V.shape, "Q, K, V must have same shape"\n```\n\nAlso verify that the head dimension divides the embedding dimension if using multi-head attention. Use systematic checks after each projection and reshaping to catch mismatches early, preventing cryptic runtime errors in matrix multiplications.\n\n---\n\n### Off-by-One Errors in Sequence Length and Padding\nAttention computations rely on accurate sequence lengths. Off-by-one errors commonly occur when handling padding tokens or slicing sequences:\n\n- Confirm that padding tokens are correctly included in masks to avoid attending to actual padding.\n- Be careful when indexing sequences; for example, `seq_len` should match the input tensor’s second dimension.\n- When passing masks, dimensions must align: mask shape usually `(batch_size, seq_len)` or `(batch_size, seq_len, seq_len)` depending on context.\n\nA typical mistake is misaligning masks with input lengths, resulting in attention attending to padding tokens or leaking information. Always:\n\n1. Match mask dimensions with the query sequence length.\n2. Debug by visualizing mask coverage to confirm correct masking of padded positions.\n\n---\n\n### Importance of Attention Masks in Autoregressive Models\nIn autoregressive tasks like language generation, preventing future token leakage is critical. Attention masks enforce causality by disallowing tokens to attend to subsequent tokens:\n\n- Use a causal mask (lower-triangular matrix) applied before softmax in scaled dot-product attention.\n- Improper or missing masks result in the model having access to future tokens, causing training leakage and inflated performance metrics.\n\nExample causal mask creation:\n\n```python\ncausal_mask = torch.tril(torch.ones(seq_len, seq_len)).bool()\n# Apply mask by adding large negative values to masked logits:\nscores.masked_fill_(~causal_mask, float(\'-inf\'))\n```\n\nDouble-check mask shape and application point—masks must be applied **before** softmax to zero out disallowed attention weights.\n\n---\n\n### Debugging Tips: Logging Attention Weights and Intermediate Outputs\nTo verify self-attention correctness, log and inspect intermediate values:\n\n- Print attention weights after softmax: confirm each row sums to 1 within numerical tolerance.\n- Visualize attention distributions for sample inputs to identify skewed or uniform patterns indicating bugs.\n- Check QKᵀ (scores) distributions before masking and after masking—is masking effective?\n\nExample validation:\n\n```python\nattn_weights = torch.softmax(scores, dim=-1)\nassert torch.allclose(attn_weights.sum(dim=-1), torch.ones_like(attn_weights.sum(dim=-1)), atol=1e-5)\n```\n\nLogging intermediate tensors helps trace issues like broken projections, incorrect masking, or dimension errors early.\n\n---\n\n### Performance Bottlenecks and Optimization Strategies\nSelf-attention’s quadratic complexity in sequence length demands efficient implementation:\n\n- Profile matrix multiplications using tools like PyTorch’s `torch.profiler` or NVIDIA Nsight Systems.\n- Use mixed precision (`torch.cuda.amp`) to reduce memory and speed up calculations.\n- Minimize Python-side copies and repeatedly calling `.cpu()` or `.numpy()` on GPU tensors.\n- For very long sequences, consider spars ...
#   '## Testing, Observability, and Performance Considerations\n\n### Unit Testing Self-Attention Modules\n\nTo ensure correctness of your self-attention implementation, write unit tests covering core invariants:\n\n- **Attention weights sum to one:** For each query position, the attention distribution over all keys must sum to exactly 1.0. Verify with code like:\n\n  ```python\n  attention = model.get_attention_weights(input_tensor)\n  sums = attention.sum(dim=-1)  # sum over keys dimension\n  assert torch.allclose(sums, torch.ones_like(sums), atol=1e-6)\n  ```\n\n- **Output shape validation:** The output tensor must conform to expected shape `(batch_size, seq_len, hidden_dim)`. For instance:\n\n  ```python\n  output = model(input_tensor)\n  assert output.shape == (batch_size, seq_len, hidden_dim)\n  ```\n\nThese tests catch common bugs in normalization or shape broadcasting.\n\n### Handling Edge Cases: Very Short and Long Sequences\n\nShort sequences (length 1-2) test if your attention code handles minimal shapes without indexing errors or unnecessary computations. Verify that the attention matrix reduces correctly.\n\nExtremely long sequences introduce memory and runtime challenges due to the quadratic cost of the attention score matrix (`seq_len^2`). Strategies to handle these include:\n\n- **Chunking:** Split input into overlapping chunks, compute attention locally.\n- **Sparse attention:** Use masked or windowed attention to limit keys searched by each query.\n- **Approximate methods:** Perform low-rank or kernelized approximations to reduce time and memory.\n\nGraceful handling involves setting maximum sequence lengths and fallback logic to avoid OOM errors during inference.\n\n### Observability: Logging and Metrics for Attention\n\nFor production monitoring:\n\n- **Log attention distributions:** Dump attention matrices or summaries periodically for debugging and model interpretability.\n- **Track sparsity:** Define sparsity as percentage of attention weights below a threshold (e.g., 0.01). High sparsity may indicate model collapse or redundancy.\n- **Measure entropy:** Compute per-sample entropy of attention distributions to assess focus sharpness:\n\n  ```python\n  import torch.nn.functional as F\n  entropy = -(attention * attention.log()).sum(dim=-1).mean()\n  ```\n\nCollecting these metrics helps detect anomalies or drift in model behavior.\n\n### Performance Trade-offs and Precision\n\nBatch size impacts GPU utilization and latency—larger batches improve throughput but increase memory consumption. Choose batch size based on target latency SLA and available hardware.\n\nPrecision influences memory and speed: \n\n- **FP32** offers higher numerical stability, recommended during training.\n- **FP16 / mixed precision** halves memory and speeds up compute, preferred for inference with hardware support (e.g., NVIDIA Tensor Cores).\n\nEvaluate these options based on model convergence and hardware capabilities.\n\n### Memory Management: Gradient Checkpointing and Attention Approximation\n\nSelf-attention modules consume large memory due to storing intermediate activations:\n\n- **Gradient checkpointing:** Save memory by recomputing intermediate results during backpropagation instead of storing all activations. Implement using PyTorch’s `torch.utils.checkpoint.checkpoint()`.\n\n- **Attention approximations:** Techniques like Linformer, Performer, or Longformer reduce memory by decomposing or sparsifying attention matrices, allowing training and inference of longer sequences.\n\nUse these strategies to trade extra compute for reduced memory footprint, enabling scaling to larger models or input lengths in resource-constrained environments.',
#   '## Practical Summary and Checklist for Building Self-Attention Modules\n\nTo implement self-attention effectively, start by grasping the core mathematical foundations: computing query (Q), key (K), and value (V) matrices, scaling dot products by \\(\\sqrt{d_k}\\), applying masks, and using softmax to obtain attention weights. Extend this to multi-head attention by projecting inputs into multiple QKV sets, concatenating outputs, and applying a final linear layer for richer representations.\n\n### Implementation Checklist\n\n- **Shape Verification:**  \n  Confirm Q, K, V tensors have shapes \\((B, H, L, d_k)\\) where:  \n  - \\(B\\): batch size  \n  - \\(H\\): number of heads  \n  - \\(L\\): sequence length  \n  - \\(d_k\\): head dimension  \n  Mismatched shapes cause runtime errors or faulty attention distributions.\n\n- **Masking Correctness:**  \n  Verify masks (causal or padding) are properly broadcasted across heads and sequence dimensions before softmax, setting masked logits to \\(-\\infty\\) or a large negative constant to nullify attention.\n\n- **Numerical Stability:**  \n  Subtract the maximum logit per query before softmax to prevent overflow, e.g.,  \n  ```python\n  logits = logits - logits.max(dim=-1, keepdim=True)[0]\n  attention_weights = softmax(logits, dim=-1)\n  ```\n\n- **Testing Coverage:**  \n  Write unit tests covering:  \n  - Shape and dtype consistency  \n  - Correct masking behavior (e.g., attention weights zeroed out)  \n  - Identity and edge cases (e.g., all-zero inputs, maximum sequence length)  \n  - Gradient computations if applicable\n\n### Next Steps\n\n- Explore **relative positional encoding** to incorporate token position info more flexibly than fixed sinusoidal embeddings.  \n- Experiment with **sparse attention** variants (e.g., BigBird, Longformer) to handle long sequences efficiently by reducing compute complexity.  \n- Fine-tune transformer models on specific downstream tasks, adapting pretrained weights to domain needs.\n\n### Further Resources\n\n- Review implementations in libraries like **HuggingFace Transformers** to see optimized, production-grade code and utilities.  \n- Use profiling tools such as **PyTorch Profiler** or **TensorBoard** to benchmark attention layers, identify bottlenecks, and optimize for latency or memory.  \n\nThis checklist ensures you build self-attention modules that are correct, efficient, and extensible while providing paths to deepen transformer expertise.',
#   '## Conclusion: The Future of Self-Attention in Deep Learning\n\nSelf-attention remains a fundamental mechanism driving scalable and powerful sequence modeling in transformers. By enabling each token to dynamically weight its relationship to every other token, self-attention facilitates rich contextual understanding without fixed receptive fields, making it a cornerstone for NLP, vision, and beyond.\n\nCurrent research aggressively targets self-attention’s quadratic complexity in sequence length, with innovations like efficient transformers (e.g., Longformer, Performer), linear attention variants that approximate full attention with reduced cost, and cross-modal attention mechanisms that fuse information across text, images, and audio. These efforts aim to extend transformers to longer sequences and multi-modal tasks without prohibitive compute or memory costs.\n\nHowever, challenges persist. Quadratic scaling still limits deployment on ultra-long inputs, and attention approximation methods often involve trade-offs in accuracy or model interpretability. Developers should carefully evaluate these trade-offs relative to their application needs.\n\nWe encourage experimentation with alternative attention forms and hybrid architectures to improve speed, memory footprint, or domain-specific performance. Contributing to open-source libraries and benchmarks helps accelerate this vibrant ecosystem.\n\nFor further exploration, consider these resources:\n- Papers with Code: Transformer and Efficient Attention collections\n- The Annotated Transformer by Harvard NLP\n- Hugging Face forums and GitHub repositories\n\nStaying engaged with the community and ongoing research ensures your work with self-attention remains cutting-edge and impactful.'],
#  'final': '# Demystifying Self-Attention: A Developer\'s Guide to Understanding and Implementing Transformer Mechanisms\n\n## Introduction to Self-Attention and Its Importance\n\nSelf-attention is a mechanism that computes a representation of a sequence by relating different positions within that same sequence. Unlike methods that process input tokens independently or in strict order, self-attention dynamically weighs the influence of each token on every other token, enabling the model to capture contextual relationships regardless of their distance. Concretely, for each position in the input sequence, self-attention produces a weighted sum of all positions’ embeddings, where the weights reflect pairwise relevance learned via query-key similarity.\n\nTraditional sequential models like RNNs or CNNs face challenges when modeling long-range dependencies. RNNs suffer from vanishing gradients and must process data token-by-token, limiting their ability to capture distant interactions efficiently. CNNs leverage local filters, requiring many layers to capture broad context. Self-attention addresses these by allowing direct connections between any two positions in the sequence, enabling global context modeling in a single layer. This leads to better gradient flow and more flexible representations.\n\nSelf-attention is especially effective in domains such as:\n\n- **Natural Language Processing (NLP):** It models word dependencies regardless of their distance, improving tasks like translation or sentiment analysis.\n- **Vision Transformers (ViT):** Applies self-attention over image patches to capture global spatial relationships, replacing convolutions.\n- **Speech Recognition:** Captures temporal dependencies across audio frames more effectively than traditional methods.\n\nA key advantage of self-attention over recurrent approaches is scalability via parallelism. Since all sequence positions are processed simultaneously, implementations can leverage GPU acceleration more efficiently, leading to significant speedups during training and inference.\n\nThe transformer architecture is the primary consumer of self-attention modules. Transformers stack multiple self-attention layers combined with feed-forward networks to build powerful sequence models, forming the backbone of state-of-the-art models like BERT and GPT. This architecture’s success underscores the foundational importance of self-attention in modern deep learning.\n\n## Core Concepts and Mathematical Formulation of Self-Attention\n\nSelf-attention is a mechanism that allows each element in a sequence to attend to other elements dynamically, enabling models like Transformers to capture contextual relationships effectively. The core components are **Query (Q)**, **Key (K)**, and **Value (V)** matrices, which are linear projections of the input embeddings:\n\n- **Query (Q)**: Represents the current element seeking information.\n- **Key (K)**: Represents candidates to be attended to.\n- **Value (V)**: Holds the actual information to aggregate based on attention scores.\n\nThese components are obtained by multiplying the input matrix \\(X \\in \\mathbb{R}^{n \\times d}\\) (with sequence length \\(n\\) and embedding dimension \\(d\\)) by learned weight matrices \\(W_Q, W_K, W_V \\in \\mathbb{R}^{d \\times d_k}\\):\n\n\\[\nQ = X W_Q, \\quad K = X W_K, \\quad V = X W_V\n\\]\n\n### Scaled Dot-Product Attention Formula\n\nThe attention mechanism computes a weighted sum of values, where weights reflect the similarity between queries and keys. Mathematically:\n\n\\[\n\\text{Attention}(Q, K, V) = \\text{softmax} \\left( \\frac{Q K^\\top}{\\sqrt{d_k}} \\right) V\n\\]\n\nBreaking down the terms:\n\n- \\(Q K^\\top\\) computes the raw compatibility scores (dot products) between each query and key vector pair.\n- Dividing by \\(\\sqrt{d_k}\\) scales the scores to avoid large magnitudes, which can push softmax into regions with very small gradients, causing learning instabilities.\n- The softmax f ...
